# %%
states = []
states.append({"fullName": "Alabama", "abbreviatedName": "AL", "filingDate": "03/01/2025"})
states.append({"fullName": "Alaska", "abbreviatedName": "AK", "filingDate": ""})
states.append({"fullName": "Alberta", "abbreviatedName": "AB", "filingDate": ""})
states.append({"fullName": "American Samoa", "abbreviatedName": "AS", "filingDate": ""})
states.append({"fullName": "Arizona", "abbreviatedName": "AZ", "filingDate": "03/01/2025"})
states.append({"fullName": "Arkansas", "abbreviatedName": "AR", "filingDate": "03/01/2025"})
states.append({"fullName": "Armed Forces (AE)", "abbreviatedName": "AE", "filingDate": ""})
states.append({"fullName": "Armed Forces Americas", "abbreviatedName": "AA", "filingDate": ""})
states.append({"fullName": "Armed Forces Pacific", "abbreviatedName": "AP", "filingDate": ""})
states.append({"fullName": "British Columbia", "abbreviatedName": "BC", "filingDate": ""})
states.append({"fullName": "California", "abbreviatedName": "CA", "filingDate": ""})
states.append({"fullName": "Colorado", "abbreviatedName": "CO", "filingDate": ""})
states.append({"fullName": "Connecticut", "abbreviatedName": "CT", "filingDate": "03/01/2025"})
states.append({"fullName": "Delaware", "abbreviatedName": "DE", "filingDate": "03/01/2025"})
states.append({"fullName": "Florida", "abbreviatedName": "FL", "filingDate": ""})
states.append({"fullName": "Georgia", "abbreviatedName": "GA", "filingDate": "03/01/2025"})
states.append({"fullName": "Guam", "abbreviatedName": "GU", "filingDate": ""})
states.append({"fullName": "Hawaii", "abbreviatedName": "HI", "filingDate": ""})
states.append({"fullName": "Idaho", "abbreviatedName": "ID", "filingDate": ""})
states.append({"fullName": "Illinois", "abbreviatedName": "IL", "filingDate": "03/01/2025"})
states.append({"fullName": "Indiana", "abbreviatedName": "IN", "filingDate": "03/01/2025"})
states.append({"fullName": "Iowa", "abbreviatedName": "IA", "filingDate": "03/01/2025"})
states.append({"fullName": "Kansas", "abbreviatedName": "KS", "filingDate": ""})
states.append({"fullName": "Kentucky", "abbreviatedName": "KY", "filingDate": "03/01/2025"})
states.append({"fullName": "Louisiana", "abbreviatedName": "LA", "filingDate": ""})
states.append({"fullName": "Maine", "abbreviatedName": "ME", "filingDate": ""})
states.append({"fullName": "Manitoba", "abbreviatedName": "MB", "filingDate": ""})
states.append({"fullName": "Maryland", "abbreviatedName": "MD", "filingDate": ""})
states.append({"fullName": "Massachusetts", "abbreviatedName": "MA", "filingDate": ""})
states.append({"fullName": "Michigan", "abbreviatedName": "MI", "filingDate": "03/01/2025"})
states.append({"fullName": "Minnesota", "abbreviatedName": "MN", "filingDate": "03/01/2025"})
states.append({"fullName": "Mississippi", "abbreviatedName": "MS", "filingDate": "03/01/2025"})
states.append({"fullName": "Missouri", "abbreviatedName": "MO", "filingDate": ""})
states.append({"fullName": "Montana", "abbreviatedName": "MT", "filingDate": ""})
states.append({"fullName": "Nebraska", "abbreviatedName": "NE", "filingDate": "03/01/2025"})
states.append({"fullName": "Nevada", "abbreviatedName": "NV", "filingDate": "03/01/2025"})
states.append({"fullName": "New Brunswick", "abbreviatedName": "NB", "filingDate": ""})
states.append({"fullName": "New Hampshire", "abbreviatedName": "NH", "filingDate": ""})
states.append({"fullName": "New Jersey", "abbreviatedName": "NJ", "filingDate": "03/01/2025"})
states.append({"fullName": "New Mexico", "abbreviatedName": "NM", "filingDate": "03/01/2025"})
states.append({"fullName": "New York", "abbreviatedName": "NY", "filingDate": ""})
states.append({"fullName": "Newfoundland", "abbreviatedName": "NF", "filingDate": ""})
states.append({"fullName": "North Carolina", "abbreviatedName": "NC", "filingDate": ""})
states.append({"fullName": "North Dakota", "abbreviatedName": "ND", "filingDate": ""})
states.append({"fullName": "Northwest Territories", "abbreviatedName": "NT", "filingDate": ""})
states.append({"fullName": "Nova Scotia", "abbreviatedName": "NS", "filingDate": ""})
states.append({"fullName": "Nunavut", "abbreviatedName": "NU", "filingDate": ""})
states.append({"fullName": "Ohio", "abbreviatedName": "OH", "filingDate": "03/01/2025"})
states.append({"fullName": "Oklahoma", "abbreviatedName": "OK", "filingDate": ""})
states.append({"fullName": "Ontario", "abbreviatedName": "ON", "filingDate": ""})
states.append({"fullName": "Oregon", "abbreviatedName": "OR", "filingDate": "03/01/2025"})
states.append({"fullName": "Pennsylvania", "abbreviatedName": "PA", "filingDate": "03/01/2025"})
states.append({"fullName": "Prince Edward Island", "abbreviatedName": "PE", "filingDate": ""})
states.append({"fullName": "Puerto Rico", "abbreviatedName": "PR", "filingDate": ""})
states.append({"fullName": "Quebec", "abbreviatedName": "QC", "filingDate": ""})
states.append({"fullName": "Rhode Island", "abbreviatedName": "RI", "filingDate": ""})
states.append({"fullName": "Saskatchewan", "abbreviatedName": "SK", "filingDate": ""})
states.append({"fullName": "South Carolina", "abbreviatedName": "SC", "filingDate": "03/01/2025"})
states.append({"fullName": "South Dakota", "abbreviatedName": "SD", "filingDate": "03/01/2025"})
states.append({"fullName": "Tennessee", "abbreviatedName": "TN", "filingDate": "03/01/2025"})
states.append({"fullName": "Texas", "abbreviatedName": "TX", "filingDate": "03/01/2025"})
states.append({"fullName": "Utah", "abbreviatedName": "UT", "filingDate": "03/01/2025"})
states.append({"fullName": "Vermont", "abbreviatedName": "VT", "filingDate": ""})
states.append({"fullName": "Virgin Islands", "abbreviatedName": "VI", "filingDate": ""})
states.append({"fullName": "Virginia", "abbreviatedName": "VA", "filingDate": ""})
states.append({"fullName": "Washington", "abbreviatedName": "WA", "filingDate": ""})
states.append({"fullName": "West Virginia", "abbreviatedName": "WV", "filingDate": "03/01/2025"})
states.append({"fullName": "Wisconsin", "abbreviatedName": "WI", "filingDate": "03/01/2025"})
states.append({"fullName": "Wyoming", "abbreviatedName": "WY", "filingDate": "03/01/2025"})
states.append({"fullName": "Yukon Territory", "abbreviatedName": "YT", "filingDate": ""})
states.append({"fullName": "District of Columbia", "abbreviatedName": "DC", "filingDate": ""})

# %%
import csv

csv_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/NewRAPRatesRABRatingFactors/RAP New Rates by State-Table 1.csv"
sql_script_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/insert_rates.sql"

with open(csv_path, "r", newline="\n") as csv_file, open(sql_script_path, "w") as sql_script:
    reader = csv.DictReader(csv_file)
    for line in reader:
        abbreviated_state = next((x['abbreviatedName'] for x in states if x['fullName'] == line['State']), None)
        if abbreviated_state:
            sql_script.write(f"""
INSERT INTO navappraiserrates (
    STATE, 
    STATEFULLTEXT, 
    REVDATE,
    APPTEMPLATELET,
    RES1,
    RES2,
    RES3,
    RES4,
    RES5,
    RES6,
    RES7,
    RES8,
    COMM1,
    COMM2,
    COMM3,
    COMM4,
    COMM5,
    COMM6,
    COMM7,
    COMM8
) 
VALUES (
    '{abbreviated_state}', 
    '{line['State']}', 
    '0624',
    'C',
    {line['Residential RAP Rates with $0 deductible (300K/600K)']},
    {line['Residential RAP Rates with $0 deductible (500K/1M)']},
    {line['Residential RAP Rates with $0 deductible (1M/1M)']},
    {line['Residential RAP Rates with $0 deductible (1M/2M)']},
    {line['Residential RAP Rates with $500 deductible (300K/600K)']},
    {line['Residential RAP Rates with $500 deductible (500K/1M)']},
    {line['Residential RAP Rates with $500 deductible (1M/1M)']},
    {line['Residential RAP Rates with $500 deductible (1M/2M)']},
    {line['Commercial RAP Rates with $0 deductible (300K/600K)']},
    {line['Commercial RAP Rates with $0 deductible (500K/1M)']},
    {line['Commercial RAP Rates with $0 deductible (1M/1M)']},
    {line['Commercial RAP Rates with $0 deductible (1M/2M)']},
    {line['Commercial RAP Rates with $500 deductible (300K/600K)']},
    {line['Commercial RAP Rates with $500 deductible (500K/1M)']},
    {line['Commercial RAP Rates with $500 deductible (1M/1M)']},
    {line['Commercial RAP Rates with $500 deductible (1M/2M)']}
);
                             """)

# %%
import csv

csv_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/NewRAPRatesRABRatingFactors/RAB New State Relativity Factor-Table 1.csv"
sql_script_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/insert_relativity_factors.sql"

with open(csv_path, "r", newline="\n") as csv_file, open(sql_script_path, "w") as sql_script:
    reader = csv.DictReader(csv_file)
    for line in reader:
        abbreviated_state = next((x['abbreviatedName'] for x in states if x['fullName'] == line['State']), None)
        if abbreviated_state:
            sql_script.write(f"""
INSERT INTO state_relativity_factors (
    state, 
    old_factor, 
    new_factor,
) 
VALUES (
    '{abbreviated_state}',
    {line['old/current State Factor']},
    {line['NEW RAB State Factor']}
);
                             """)

# %%
class_of_svc_hi = [
    1.25, # Residential Real Estate Sales/Leasing
    1.50, # Commercial Real estate Sales/Leasing
    1.75, # Commercial Appraisal and Business Brokerage
    1.50, # Residential Appraisal
    1.50, # Mortgage Broker
    1.50, # Sale of Owned Residential Property
    2.25, # Property Management
    2.25, # Real Estate Consulting/Counseling
    1.35, # All Other
    0 # Empty
]

class_of_svc_lo = [
    0.75, # Residential Real Estate Sales/Leasing
    1.00, # Commercial Real estate Sales/Leasing
    1.25, # Commercial Appraisal and Business Brokerage
    1.00, # Residential Appraisal
    1.00, # Mortgage Broker
    1.00, # Sale of Owned Residential Property
    1.75, # Property Management
    1.75, # Real Estate Consulting/Counseling
    0.85, # All Other
    0 # Empty
]

# %%
for i in range(1, 60):
    print(f"SUM(CASE WHEN \"irms[{i}]\" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms{i},")
# Out:
# SUM(CASE WHEN "irms[1]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms1,
# SUM(CASE WHEN "irms[2]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms2,
# SUM(CASE WHEN "irms[3]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms3,
# SUM(CASE WHEN "irms[4]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms4,
# SUM(CASE WHEN "irms[5]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms5,
# SUM(CASE WHEN "irms[6]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms6,
# SUM(CASE WHEN "irms[7]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms7,
# SUM(CASE WHEN "irms[8]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms8,
# SUM(CASE WHEN "irms[9]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms9,
# SUM(CASE WHEN "irms[10]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms10,
# SUM(CASE WHEN "irms[11]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms11,
# SUM(CASE WHEN "irms[12]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms12,
# SUM(CASE WHEN "irms[13]" <> 0 THEN 1 ELSE 0 END) AS CountOfNonNullIrms13,
# ...

# %%
import psycopg2
from psycopg2 import sql

# input_csv_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/REGAstateWork/GAstate_Prod_BeforeSchemaChange.csv"
input_csv_path = "/Users/kristoferpearson/Dev/Landy/Temp/GAstate_Prod_BeforeSchemaChange.csv"
# output_csv_path = "/Volumes/pdf_files/garf/Kris/Projects/RapFiling_20241108/_Deployment/Data/RE/GAstate.csv"
output_csv_path = "/Users/kristoferpearson/Dev/Landy/Temp/GAstate.csv"

db_params = {
    "host": 'localhost',
    "database": "landy",
    "user": 'kristoferpearson',
    "password": ''
}

header = "st_ind^state_amend[1]^state_amend[2]^state_amend[3]^state_amend[4]^state_amend1[1]^state_amend1[2]^state_amend1[3]^state_amend1[4]^state_amend1[5]^state_amend1[6]^state_amend1[7]^state_amend10[1]^state_amend10[2]^state_amend10[3]^state_amend10[4]^surplus_lic^state^nj_surch[1]^nj_surch[2]^fl_surch[1]^fl_surch[2]^surplus_lines^pro_rata^short_rate^pad1[1]^pad1[2]^pad1[3]^pad1[4]^pad1[5]^pad1[6]^pad1[7]^pad1[8]^pad1[9]^pad12^state_fraud^apr_zero_ded^ras_zero_ded^endor_44_ok^bool_pad[1]^bool_pad[2]^bool_pad[3]^bool_pad[4]^bool_pad[5]^non_renewal^cancel_days^irm_min^irm_max^padint1^rate_per_k[1]^rate_per_k[2]^rate_per_k[3]^rate_per_k[4]^rate_per_k[5]^rate_per_k[6]^rate_per_k[7]^rate_per_k[8]^rate_per_k[9]^rate_per_k[10]^rate_per_k[11]^rate_per_k[12]^st_relativity^rel_filing^wv_tax[1]^wv_tax[2]^ilf_ceol[1]^ilf_ceol[2]^ilf_ceol[3]^ilf_ceol[4]^ilf_ceol[5]^ilf_ceol[6]^ilf_ceol[7]^ilf_ceol[8]^ilf_ceol[9]^ilf_ceol[10]^ilf_ceol[11]^ilf_ceol[12]^ilf_ceol[13]^ilf_ceol[14]^ilf_ceil[1]^ilf_ceil[2]^ilf_ceil[3]^ilf_ceil[4]^ilf_ceil[5]^ilf_ceil[6]^ilf_ceil[7]^ilf_ceil[8]^ilf_ceil[9]^ilf_ceil[10]^ilf_ceil[11]^ilf_ceil[12]^ilf_ceil[13]^ilf_ceil[14]^le_ded[1]^le_ded[2]^le_ded[3]^le_ded[4]^le_ded[5]^le_ded[6]^le_ded[7]^le_ded[8]^le_ded[9]^le_ded[10]^le_ded[11]^le_ded[12]^le_ded[13]^le_ded[14]^lo_ded[1]^lo_ded[2]^lo_ded[3]^lo_ded[4]^lo_ded[5]^lo_ded[6]^lo_ded[7]^lo_ded[8]^lo_ded[9]^lo_ded[10]^lo_ded[11]^lo_ded[12]^lo_ded[13]^lo_ded[14]^class_of_svc[1]^class_of_svc[2]^class_of_svc[3]^class_of_svc[4]^class_of_svc[5]^class_of_svc[6]^class_of_svc[7]^class_of_svc[8]^class_of_svc[9]^class_of_svc[10]^classofsvc_fil[1]^classofsvc_fil[2]^classofsvc_fil[3]^classofsvc_fil[4]^broker_apprv^appr_apprv^nj_date[1]^nj_date[2]^fl_date[1]^fl_date[2]^filing_date[1]^filing_date[2]^seller_shield^date_pad[1]^date_pad[2]^date_pad[3]^layer0[1]^layer0[2]^layer0[3]^layer0[4]^layer0[5]^layer1[1]^layer1[2]^layer1[3]^layer1[4]^layer1[5]^layer2[1]^layer2[2]^layer2[3]^layer2[4]^layer2[5]^layer3[1]^layer3[2]^layer3[3]^layer3[4]^layer3[5]^layer4[1]^layer4[2]^layer4[3]^layer4[4]^layer4[5]^layer5[1]^layer5[2]^layer5[3]^layer5[4]^layer5[5]^layer6[1]^layer6[2]^layer6[3]^layer6[4]^layer6[5]^layer7[1]^layer7[2]^layer7[3]^layer7[4]^layer7[5]^apr_resident[1]^apr_resident[2]^apr_resident[3]^apr_resident[4]^apr_resident[5]^apr_commercial[1]^apr_commercial[2]^apr_commercial[3]^apr_commercial[4]^apr_commercial[5]^apr_resident2[1]^apr_resident2[2]^apr_resident2[3]^apr_resident2[4]^apr_commercial2[1]^apr_commercial2[2]^apr_commercial2[3]^apr_commercial2[4]^min_fdd[1]^min_fdd[2]^min_fdd[3]^min_fdd[4]^min_fdd[5]^min_fdd[6]^min_fdd[7]^min_fdd[8]^min_fdd[9]^min_fdd[10]^min_fdd[11]^min_fdd[12]^apr_resident3[1]^apr_resident3[2]^apr_resident3[3]^apr_resident3[4]^apr_resident3[5]^apr_resident3[6]^apr_resident3[7]^apr_resident3[8]^apr_commercial3[1]^apr_commercial3[2]^apr_commercial3[3]^apr_commercial3[4]^apr_commercial3[5]^apr_commercial3[6]^apr_commercial3[7]^apr_commercial3[8]^class_of_svc_hi[1]^class_of_svc_hi[2]^class_of_svc_hi[3]^class_of_svc_hi[4]^class_of_svc_hi[5]^class_of_svc_hi[6]^class_of_svc_hi[7]^class_of_svc_hi[8]^class_of_svc_hi[9]^class_of_svc_hi[10]^class_of_svc_lo[1]^class_of_svc_lo[2]^class_of_svc_lo[3]^class_of_svc_lo[4]^class_of_svc_lo[5]^class_of_svc_lo[6]^class_of_svc_lo[7]^class_of_svc_lo[8]^class_of_svc_lo[9]^class_of_svc_lo[10]^zero_ded_factor^\n"

with open(input_csv_path, "r") as input_csv, \
        open(output_csv_path, "w") as output_csv, \
        psycopg2.connect(**db_params) as conn:
    for line in input_csv:
        values = line.split('^')
        if values[0] == "st_ind":
            print("Adding to header...")
            # Write out the header with the new columns
            output_csv.write(header)
        else:
            state_full_name = next((x['fullName'] for x in states if x['abbreviatedName'] == values[0]), None)
            filing_date = next((x['filingDate'] for x in states if x['abbreviatedName'] == values[0]), None)
            # Get the new rates data and insert it into the row accordingly
            cur = conn.cursor()
            query = sql.SQL(f"SELECT * FROM RAP_State_Rates WHERE \"State\" = '{state_full_name}';")
            cur.execute(query)
            row = cur.fetchone()

            query = sql.SQL(f"SELECT * FROM state_relativity_factors WHERE \"state\" = '{values[0]}'")
            cur.execute(query)
            relativity_factors = cur.fetchone()

            new_rates = ""
            if row is None:
                print(f"No row for {state_full_name}")
                new_rates = "^".join(["0.00"] * 16) + "^" + "^".join(["0"] * 20)
            else:
                new_rates = "^".join(['{:,.2f}'.format(value) if value is not None else "0.00" for value in row[1:-1]])
                new_rates += "^" + "^".join(['{:,.2f}'.format(class_of_svc) for class_of_svc in class_of_svc_hi])
                new_rates += "^" + "^".join(['{:,.2f}'.format(class_of_svc) for class_of_svc in class_of_svc_lo])
                # Set the default broker filing equal to the next filing
                values[1] = values[3]
                # Update the next broker filing to 0624
                values[3] = "0624"
                # Set the default appraiser filing equal to the next filing
                values[5] = values[7]
                # Update the next appraiser filing to 0624
                values[7] = "0624"
                # Update old ratings 
                values[124] = "1.25"
                values[127] = "2.00"
                print(f"Updating filing date of {values[141]} for {values[0]} to {filing_date}")
                values[141] = filing_date
                values[142] = filing_date
            values[61] = values[62]
            new_rates += "^-0.2"
            if relativity_factors is None:
                values[62] = "0.00"
            else:
                values[62] = '{:,.2f}'.format(relativity_factors[2])
            joined_existing_values = "^".join(values[:-1])
            output_row = f"{joined_existing_values}^{new_rates}^{values[-1]}"
            output_csv.write(output_row)
# Out:
# Adding to header...
# Updating filing date of 02/01/2020 for NJ to 03/01/2025
# Updating filing date of  for NY to
# Updating filing date of 04/01/2020 for CT to 03/01/2025
# Updating filing date of 01/01/2021 for FL to
# Updating filing date of 06/01/2020 for IL to 03/01/2025
# Updating filing date of 04/01/2020 for MD to
# Updating filing date of 02/01/2020 for MI to 03/01/2025
# Updating filing date of 02/01/2020 for PA to 03/01/2025
# Updating filing date of 08/01/2020 for MA to
# Updating filing date of 02/01/2020 for AZ to 03/01/2025
# Updating filing date of 02/01/2020 for TX to 03/01/2025
# Updating filing date of 02/01/2021 for CO to
# Updating filing date of 03/01/2020 for HI to
# Updating filing date of 02/01/2020 for OH to 03/01/2025
# Updating filing date of 02/01/2020 for OR to 03/01/2025
# Updating filing date of 08/01/2020 for RI to
# Updating filing date of 02/01/2020 for TN to 03/01/2025
# Updating filing date of 08/01/2020 for WA to
# ...
